# %%
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from os import listdir
from PIL import Image

# %% [markdown]
# ### Transform images into dataframe.

# %%
def transform_into_df(path,images,width,height):
    images = sorted(images)
    columns = [*range(0,(width* height))].append('Label')
    outdf=pd.DataFrame(columns=)
    for image in images:
        img = Image.open(path+image)
        pixels = np.array(img.getdata())/255
        outdf.loc[image]=pixels
        Label = image[2]
        outdf.loc[image]= [image,Label]
        
                
    return outdf

# %% [markdown]
# Train Dataframe

# %%
train_df = transform_into_df('Train/',listdir('Train/'),12,12)
print("Train dataset has {} images with {} pixels each.".format(train_df.shape[0],train_df.shape[1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-3d916e71444f> in <module>
# ----> 1 train_df = transform_into_df('Train/',listdir('Train/'),12,12)
#       2 print("Train dataset has {} images with {} pixels each.".format(train_df.shape[0],train_df.shape[1]))
#
# <ipython-input-85-cbedc1e828d0> in transform_into_df(path, images, width, height)
#       7         pixels = np.array(img.getdata())/255
#       8         Label = image[2]
# ----> 9         outdf.loc[image]=np.append(pixels,Label)
#      10
#      11     return outdf
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     187             key = com._apply_if_callable(key, self.obj)
#     188         indexer = self._get_setitem_indexer(key)
# --> 189         self._setitem_with_indexer(indexer, value)
#     190
# ...

# %%
train_df.head(10)
# Out:
#                0         1         2         3         4         5    \
# A1a1.jpg  0.000000  1.000000  0.984314  0.000000  1.000000  0.039216
# A1a2.jpg  0.031373  0.976471  0.972549  0.980392  0.972549  1.000000
# A1a3.jpg  0.000000  0.062745  0.964706  0.972549  0.011765  1.000000
# A1a4.jpg  0.000000  0.000000  0.976471  1.000000  1.000000  0.917647
# A1a5.jpg  1.000000  0.078431  0.000000  0.964706  1.000000  0.972549
# A1a6.jpg  0.000000  0.031373  0.968627  0.972549  1.000000  0.960784
# A1a7.jpg  0.000000  0.003922  0.972549  0.984314  1.000000  1.000000
# A1b1.jpg  1.000000  0.737255  1.000000  0.929412  0.988235  1.000000
# A1b2.jpg  0.713725  1.000000  0.964706  0.011765  1.000000  0.117647
# A1b3.jpg  0.717647  1.000000  0.949020  0.980392  0.996078  0.113725
#
#                6         7         8         9      ...          134  \
# A1a1.jpg  0.949020  1.000000  0.988235  0.972549    ...     0.972549
# ...

# %% [markdown]
# Test DataFrame

# %%
test_df = transform_into_df('Test/',listdir('Test/'),12,12)
print("Test dataset has {} images with {} pixels each.".format(test_df.shape[0],test_df.shape[1]))
# Out:
# Test dataset has 52 images with 144 pixels each.

# %%
test_df.head()
# Out:
#                0         1         2         3         4         5    \
# A1a8.jpg  0.000000  0.121569  0.000000  0.980392  0.972549  0.015686
# A1a9.jpg  0.000000  0.172549  0.984314  0.913725  1.000000  0.921569
# A1b8.jpg  1.000000  0.909804  0.988235  0.027451  0.580392  0.000000
# A1b9.jpg  0.698039  0.780392  0.972549  0.980392  1.000000  0.094118
# A1c8.jpg  0.039216  0.000000  1.000000  0.768627  0.984314  0.917647
#
#                6         7         8         9      ...          134  \
# A1a8.jpg  0.968627  0.945098  1.000000  0.992157    ...     1.000000
# A1a9.jpg  1.000000  0.917647  1.000000  0.000000    ...     0.011765
# A1b8.jpg  0.019608  0.000000  0.000000  0.062745    ...     1.000000
# A1b9.jpg  0.000000  0.007843  0.011765  0.000000    ...     0.996078
# A1c8.jpg  0.992157  1.000000  1.000000  0.000000    ...     0.035294
#
#                135  136       137       138       139       140       141  \
# ...

# %% [markdown]
# ### Extract labels.

# %%
def create_labels(paths,images):
    counter = 0
    outdf = pd.DataFrame(columns = ['ImageId','Label'])
    images = sorted(images)
    for image in images:
        Label = image[2]
        outdf.loc[counter]= [image,Label]
        counter+=1
                
    return outdf

# %%
train_labels = create_labels('Train/',listdir('Train/'))
train_df['Label'] =pd.Series(train_labels['Label'])
train_df.head()
# Out:
#                  0         1         2         3         4         5  \
# A1a1.jpg  0.000000  1.000000  0.984314  0.000000  1.000000  0.039216
# A1a2.jpg  0.031373  0.976471  0.972549  0.980392  0.972549  1.000000
# A1a3.jpg  0.000000  0.062745  0.964706  0.972549  0.011765  1.000000
# A1a4.jpg  0.000000  0.000000  0.976471  1.000000  1.000000  0.917647
# A1a5.jpg  1.000000  0.078431  0.000000  0.964706  1.000000  0.972549
#
#                  6         7         8         9  ...         135       136  \
# A1a1.jpg  0.949020  1.000000  0.988235  0.972549  ...    1.000000  0.941176
# A1a2.jpg  0.992157  0.949020  0.988235  1.000000  ...    1.000000  0.984314
# A1a3.jpg  0.000000  1.000000  0.941176  0.050980  ...    1.000000  0.890196
# A1a4.jpg  0.023529  1.000000  0.968627  1.000000  ...    0.000000  1.000000
# A1a5.jpg  0.972549  0.960784  0.992157  0.996078  ...    0.003922  0.933333
#
#                137       138       139       140       141       142  \
# ...
